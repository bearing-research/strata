# %% [markdown]
# # Titanic-style classifier
#
# Toy survival data (no Kaggle API) — exercises `!pip install` capture,
# variable rebinding (`df = df.dropna()`), `;`-suppression, and
# multi-cell DAG flow.

# %%
# !pip install scikit-learn pandas numpy

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
rng = np.random.default_rng(0)
n = 200
df = pd.DataFrame(
    {
        "age": rng.uniform(0, 80, n),
        "fare": rng.exponential(20, n),
        "sex": rng.integers(0, 2, n),
    }
)
df["survived"] = ((df["sex"] == 1) | (df["age"] < 12)).astype(int)

# %%
df = df.dropna()
df.head();

# %%
X = df[["age", "fare", "sex"]]
y = df["survived"]

# %%
clf = RandomForestClassifier(n_estimators=20, random_state=0)
clf.fit(X, y)
accuracy = accuracy_score(y, clf.predict(X))
accuracy
