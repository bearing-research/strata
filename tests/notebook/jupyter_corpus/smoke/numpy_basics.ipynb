# %% [markdown]
# # Numpy basics
#
# Minimal numeric pipeline — exercises bare-expr auto-display.

# %%
import numpy as np

# %%
x = np.arange(10)
y = x**2

# %%
mean = y.mean()
print(f"mean = {mean}")
mean
