# %% [markdown]
# # Pandas basics
#
# Exercises trailing-`;` display-suppression and DataFrame ops.

# %%
import pandas as pd

# %%
df = pd.DataFrame({"a": [1, 2, 3], "b": [10, 20, 30]})

# %%
df.describe();  # suppressed

# %%
filtered = df[df.a > 1]
filtered
